# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('totaldf.csv')

# %%
sel = df[['YearBuilt', 'YrSinceRm', 'TotalSF', 'BsmtUnfSF' , 'WoodDeckSF', '2ndFlrSF', 'ScreenPorch', 'GrLivArea', 
           'BsmtFinSF1', 'MasVnrArea', 'LotArea', 'Pool','YearRemodAdd','KitchenQual', 'Utilities', 'FullBath',
           'FireplaceQu','BsmtFinTotSF', 'GarageArea','TotalBath','ExterQual','GarageCars','1stFlrSF','OverallQual','SalePrice']]

# %%
sel.dtypes
# Out:
# YearBuilt       float64
# YrSinceRm       float64
# TotalSF         float64
# BsmtUnfSF       float64
# WoodDeckSF      float64
# 2ndFlrSF        float64
# ScreenPorch     float64
# GrLivArea       float64
# BsmtFinSF1      float64
# MasVnrArea      float64
# LotArea         float64
# Pool              int64
# YearRemodAdd    float64
# KitchenQual     float64
# Utilities       float64
# FullBath        float64
# FireplaceQu     float64
# BsmtFinTotSF    float64
# GarageArea      float64
# TotalBath       float64
# ExterQual       float64
# GarageCars      float64
# 1stFlrSF        float64
# OverallQual     float64
# SalePrice       float64
# dtype: object

# %%
df_norm_col=(sel-sel.mean())/sel.std()

# %%
corr = sel.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 230, n=210, as_cmap=True),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %%
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(20, 220, n=210, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
numeric_all = df[['GrLivArea', 'LotFrontage','LotArea', 'Street', 'LotShape', 'LandContour', 'Utilities', 
            'LandSlope', 'OverallQual','OverallCond' , 'YearBuilt', 'YearRemodAdd',
           'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
           'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'HeatingQC', 
           'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 
           'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
           'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageYrBlt', 'GarageFinish', 
           'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 
           'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal' , 'MoSold', 'YrSold', 
           'SaleCondition', 'YrSinceRm', 'Pool', 'Misc', 'BsmtFinTotSF', 'TotalSF', 'IAstateDist', 
               'AirportDist', 'TotalBath', 'SalePrice']]

# %%
corr = numeric_all.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 20, n=210, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
