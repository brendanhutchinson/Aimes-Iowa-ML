# %%
import pandas as pd 
import numpy as np

# %%
pd.options.display.max_rows = 100

# %%
HousePriceDF = pd.read_csv("C:\\Users\\Francesco\\Desktop\\NYCDSA\\Aimes-Iowa-ML\\Francesco\\Ames_HousePrice.csv")

# %%
HousePriceDF.shape
# Out:
# (2580, 82)

# %%
HousePriceDF.columns
# Out:
# Index(['Unnamed: 0', 'PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
House2 = pd.read_csv("Ames Real Estate Data.csv")
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/3844131884.py:1: DtypeWarning: Columns (36,40,81,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   House2 = pd.read_csv("Ames Real Estate Data.csv")

# %%
House2.shape
# Out:
# (22213, 91)

# %%
HousePriceDF=HousePriceDF.drop(['Alley','Fence','MiscFeature','PoolQC'],axis =1 )

# %%
HousePriceDF['LotFrontage'] = HousePriceDF['LotFrontage'].fillna(HousePriceDF.groupby('Neighborhood')['LotFrontage'].transform('mean'))

# %%
HousePriceDF.head()
# Out:
#    Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 0           1  909176150        856     126000          30       RL
# 1           2  905476230       1049     139500         120       RL
# 2           3  911128020       1001     124900          30  C (all)
# 3           4  535377150       1039     114000          70       RL
# 4           5  534177230       1665     227000          60       RL
#
#    LotFrontage  LotArea Street LotShape  ... OpenPorchSF EnclosedPorch  \
# 0    58.769231     7890   Pave      Reg  ...           0             0
# 1    42.000000     4235   Pave      Reg  ...         105             0
# 2    60.000000     6060   Pave      Reg  ...           0            42
# 3    80.000000     8146   Pave      Reg  ...           0           168
# 4    70.000000     8400   Pave      Reg  ...          45             0
#
#   3SsnPorch ScreenPorch PoolArea MiscVal MoSold YrSold SaleType  SaleCondition
# ...

# %%
HousePriceDF.loc[HousePriceDF["Fireplaces"] == 0, "FireplaceQu"] = np.nan

# %%
HousePriceDF["FireplaceQu"].isna().sum()
# Out:
# 1241

# %%
HousePriceDF["FireplaceQu"]
# Out:
# 0        Gd
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2575     Gd
# 2576     Gd
# 2577    NaN
# 2578     TA
# 2579     TA
# Name: FireplaceQu, Length: 2580, dtype: object

# %%
garage = pd.DataFrame(HousePriceDF, columns = ['GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond'])

# %%
garage.isna().sum()
# Out:
# GarageType      127
# GarageYrBlt     129
# GarageFinish    129
# GarageCars        1
# GarageArea        1
# GarageQual      129
# GarageCond      129
# dtype: int64

# %%
garage[garage.isnull().any(axis=1)]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 17          NaN          NaN          NaN         0.0         0.0        NaN
# 22          NaN          NaN          NaN         0.0         0.0        NaN
# 44          NaN          NaN          NaN         0.0         0.0        NaN
# 48          NaN          NaN          NaN         0.0         0.0        NaN
# 50          NaN          NaN          NaN         0.0         0.0        NaN
# ...         ...          ...          ...         ...         ...        ...
# 2481        NaN          NaN          NaN         0.0         0.0        NaN
# 2488        NaN          NaN          NaN         0.0         0.0        NaN
# 2513        NaN          NaN          NaN         0.0         0.0        NaN
# 2540        NaN          NaN          NaN         0.0         0.0        NaN
# 2546        NaN          NaN          NaN         0.0         0.0        NaN
#
#      GarageCond
# 17          NaN
# ...

# %%
garage[garage.notnull().all(axis=1)]
# Out:
#      GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0        Detchd       1939.0          Unf         2.0       399.0         TA
# 1        Attchd       1984.0          Fin         1.0       266.0         TA
# 2        Detchd       1930.0          Unf         1.0       216.0         TA
# 3        Detchd       1940.0          Unf         1.0       281.0         TA
# 4        Attchd       2001.0          Fin         2.0       528.0         TA
# ...         ...          ...          ...         ...         ...        ...
# 2575     Detchd       1916.0          Unf         1.0       192.0         Fa
# 2576     Attchd       1955.0          Unf         2.0       452.0         TA
# 2577     2Types       1949.0          Unf         3.0       871.0         TA
# 2578     Attchd       2000.0          Fin         2.0       486.0         TA
# 2579     Attchd       1993.0          RFn         2.0       471.0         TA
#
#      GarageCond
# 0            TA
# ...

# %%
garage.loc[(garage["GarageType"].notnull()) & garage["GarageYrBlt"].isna()]
# Out:
#     GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 433     Detchd          NaN          NaN         NaN         NaN        NaN
# 531     Detchd          NaN          NaN         1.0       360.0        NaN
#
#     GarageCond
# 433        NaN
# 531        NaN

# %%
garage['GarageType'].loc[433] = "None"
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_19080/2144364223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garage['GarageType'].loc[433] = "None"

# %%
garage['GarageType'].loc[433]
# Out:
# 'None'

# %%
garage["GarageYrBlt"].loc[531] = 1983
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_19080/1194633844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garage["GarageYrBlt"].loc[531] = 1983

# %%
garage["GarageYrBlt"].loc[531]
# Out:
# 1983.0

# %%
garage["GarageFinish"].loc[531] = "Unf"
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_19080/247250491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garage["GarageFinish"].loc[531] = "Unf"

# %%
garage["GarageFinish"].loc[531]
# Out:
# 'Unf'

# %%
garage["GarageQual"].loc[531] = "TA"
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_19080/1373889960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garage["GarageQual"].loc[531] = "TA"

# %%
garage["GarageCond"].loc[531] = "TA"
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_19080/879288736.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   garage["GarageCond"].loc[531] = "TA"

# %%
garage.loc[531]
# Out:
# GarageType      Detchd
# GarageYrBlt     1983.0
# GarageFinish       Unf
# GarageCars         1.0
# GarageArea       360.0
# GarageQual          TA
# GarageCond          TA
# Name: 531, dtype: object

# %%
garage.isna().sum()
# Out:
# GarageType      127
# GarageYrBlt     128
# GarageFinish    128
# GarageCars        1
# GarageArea        1
# GarageQual      128
# GarageCond      128
# dtype: int64

# %%
garage.fillna("None", inplace = True)

# %%
garage.isna().sum()
# Out:
# GarageType      0
# GarageYrBlt     0
# GarageFinish    0
# GarageCars      0
# GarageArea      0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
garage.head()
# Out:
#   GarageType GarageYrBlt GarageFinish GarageCars GarageArea GarageQual  \
# 0     Detchd      1939.0          Unf        2.0      399.0         TA
# 1     Attchd      1984.0          Fin        1.0      266.0         TA
# 2     Detchd      1930.0          Unf        1.0      216.0         TA
# 3     Detchd      1940.0          Unf        1.0      281.0         TA
# 4     Attchd      2001.0          Fin        2.0      528.0         TA
#
#   GarageCond
# 0         TA
# 1         TA
# 2         Po
# 3         TA
# 4         TA

# %%
garage.value_counts()
# Out:
# GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond
# None        None         None          0.0         0.0         None        None          127
# Detchd      1973.0       Unf           1.0         264.0       TA          TA              8
#             2000.0       Unf           2.0         440.0       TA          TA              7
# Attchd      2003.0       Fin           2.0         420.0       TA          TA              7
# Detchd      1939.0       Unf           1.0         240.0       TA          TA              7
#                                                                                         ...
# Attchd      1989.0       Unf           2.0         438.0       TA          TA              1
#                                        1.0         423.0       TA          TA              1
#                          RFn           2.0         628.0       TA          TA              1
# ...

# %%
HousePriceDF.loc[HousePriceDF['MSSubClass']==120, ['LotFrontage']].mean()
# Out:
# LotFrontage    46.370279
# dtype: float64

# %%
garage.loc[garage["GarageCars"] == "None"]
# Out:
#     GarageType GarageYrBlt GarageFinish GarageCars GarageArea GarageQual  \
# 433       None        None         None       None       None       None
#
#     GarageCond
# 433       None

# %%
garage["GarageCars"].loc[433] = 0.0

# %%
garage["GarageYrBlt"]

# %%
import pandas as pd 
import numpy as np 
pd.options.display.max_rows = 100

HousePriceDF = pd.read_csv("C:\\Users\\Francesco\\Desktop\\NYCDSA\\Aimes-Iowa-ML\\Francesco\\Ames_HousePrice.csv")


# drop columns with over 98% missing values 
HousePriceDF=HousePriceDF.drop(['Alley','Fence','MiscFeature','PoolQC'],axis =1 )

# impute frontage based on mean for the neighborhood 
HousePriceDF['LotFrontage'] = HousePriceDF['LotFrontage'].fillna(HousePriceDF.groupby('Neighborhood')['LotFrontage'].transform('mean'))
HousePriceDF.loc[HousePriceDF['MSSubClass']==120, ['LotFrontage']].mean()
HousePriceDF.loc[HousePriceDF['MSSubClass']==160, ['LotFrontage']].mean()
HousePriceDF.iloc[1204,6] = 29.0
lotrow = [109,683]
HousePriceDF.loc[lotrow,['LotFrontage']]  = 46.0

# change FireplaceQu to 'None' for non existent fireplaces 
HousePriceDF.loc[HousePriceDF["Fireplaces"] == 0, "FireplaceQu"] = 'None'


# cleaning up the Basement columns 
HousePriceDF['BsmtQual'][HousePriceDF.Foundation == 'Slab'] = "None"
HousePriceDF['BsmtExposure'][HousePriceDF.Foundation == 'Slab'] = "None"
HousePriceDF['BsmtCond'][HousePriceDF.Foundation == 'Slab'] = "None"
HousePriceDF['BsmtFinType1'][HousePriceDF.Foundation == 'Slab'] = "None"
HousePriceDF['BsmtFinType2'][HousePriceDF.Foundation == 'Slab'] = "None"
HousePriceDF.loc[(HousePriceDF['BsmtFinSF1']== 0),32:36] = "None"
HousePriceDF.iloc[2434,37] = 'Unf'
HousePriceDF.iloc[912,32:36] = "None"
HousePriceDF.iloc[912,32:36] = "None"
HousePriceDF.loc[(HousePriceDF['BsmtFinSF1']== 0),'BsmtFinType2' ] = "None"
HousePriceDF.iloc[912,37] = 'None'
HousePriceDF.iloc[912,36] = 0
HousePriceDF.iloc[912,36] = 0
HousePriceDF.iloc[912,38:41] = 0 

HousePriceDF.iloc[912,48:50] = 0

HousePriceDF.iloc[2308,48:50] = 0

HousePriceDF.iloc[2442,44] = 'SBrkr'

HousePriceDF.iloc[358,27:29] = 'None'
HousePriceDF.iloc[1355,27:29] = 'None'

# MasVnrType/Area cleaning 
HousePriceDF.loc[(HousePriceDF['Exterior2nd']== 'VinylSd' )&(HousePriceDF.MasVnrType.isna()==True), ['MasVnrType' ]] = 'None'
HousePriceDF.loc[(HousePriceDF['Exterior2nd']== 'VinylSd' )&(HousePriceDF.MasVnrType.isna()==True), ['MasVnrArea' ]] = 0
# Electrical cleaning
HousePriceDF.iloc[2442,44] = 'SBrkr'




# cleaning up the Garage columns 
HousePriceDF['GarageType'].iloc[433] = "None"

HousePriceDF['GarageCars'].iloc[433] = 0.0 	#maintain float

HousePriceDF['GarageArea'].iloc[433] = 0.0  #maintain float 

HousePriceDF["GarageYrBlt"].iloc[531] = 1983

HousePriceDF["GarageFinish"].iloc[531] = "Unf"

HousePriceDF["GarageQual"].iloc[531] = "TA"

HousePriceDF["GarageCond"].iloc[531] = "TA"


# replace emtpy GarageYrBlt with YearBuilt for missing garages to maintin float 
HousePriceDF['GarageYrBlt'].fillna(HousePriceDF['YearBuilt'], inplace=True)


# DO NOT UNCOMMENT THIS UNTIL SURE WE ARE DONE IMPUTING 
HousePriceDF.fillna('None', inplace=True)
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/1358516312.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HousePriceDF['BsmtQual'][HousePriceDF.Foundation == 'Slab'] = "None"
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/1358516312.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HousePriceDF['BsmtExposure'][HousePriceDF.Foundation == 'Slab'] = "None"
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/1358516312.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
HousePriceDF.head()
# Out:
#    Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 0           1  909176150        856     126000          30       RL
# 1           2  905476230       1049     139500         120       RL
# 2           3  911128020       1001     124900          30  C (all)
# 3           4  535377150       1039     114000          70       RL
# 4           5  534177230       1665     227000          60       RL
#
#    LotFrontage  LotArea Street LotShape  ... OpenPorchSF EnclosedPorch  \
# 0    58.769231     7890   Pave      Reg  ...           0             0
# 1    42.000000     4235   Pave      Reg  ...         105             0
# 2    60.000000     6060   Pave      Reg  ...           0            42
# 3    80.000000     8146   Pave      Reg  ...           0           168
# 4    70.000000     8400   Pave      Reg  ...          45             0
#
#   3SsnPorch ScreenPorch PoolArea MiscVal MoSold YrSold SaleType  SaleCondition
# ...

# %%
House2 = pd.read_csv("Ames Real Estate Data.csv")
# Out:
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/3844131884.py:1: DtypeWarning: Columns (36,40,81,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   House2 = pd.read_csv("Ames Real Estate Data.csv")

# %%
House2.head()
# Out:
#     MapRefNo   GeoRefNo  Tier  Range                 Prop_Addr ZngCdPr  \
# 0  520400001  520400001     0      0  4599 GEORGE W CARVER AVE   FS-RL
# 1  520440010  520440010     0      0         4507 EVEREST  AVE   FS-RL
# 2  520440020  520440020     0      0         4513 EVEREST  AVE   FS-RL
# 3  520445001  520445001     0      0          3449 BARCELOS ST   FS-RL
# 4  520445010  520445010     0      0         4506 EVEREST  AVE   FS-RL
#
#   ZngCdSc ZngOLPr ZngOLSc    ClassPr_S  ... PA-Nmbr PA-PreD          PA-Strt  \
# 0     NaN     NaN     NaN  RESIDENTIAL  ...  4599.0     NaN  GEORGE W CARVER
# 1     NaN     NaN     NaN  RESIDENTIAL  ...  4507.0     NaN          EVEREST
# 2     NaN     NaN     NaN  RESIDENTIAL  ...  4513.0     NaN          EVEREST
# 3     NaN     NaN     NaN  RESIDENTIAL  ...  3449.0     NaN         BARCELOS
# 4     NaN     NaN     NaN  RESIDENTIAL  ...  4506.0     NaN          EVEREST
#
# ...

# %%
House2.shape
# Out:
# (22213, 91)

# %%
House2.isna().sum()
# Out:
# MapRefNo            0
# GeoRefNo            0
# Tier                0
# Range               0
# Prop_Addr          20
# ZngCdPr           106
# ZngCdSc         22187
# ZngOLPr         20243
# ZngOLSc         22060
# ClassPr_S           0
# ClassSc_S           0
# Legal_Pr            0
# SchD_S              0
# TxD_S               0
# MA_Ownr1            0
# MA_Ownr2        19337
# MA_Line1           14
# MA_Line2        22213
# MA_City            14
# MA_State           14
# MA_Zip1            14
# MA_Zip2          8890
# Rcrd_Yr          1907
# Rcrd_Mo          1907
# Inst1_No         1857
# Inst1_Yr         1907
# Inst1_Mo         1907
# Inst1TPr         2677
# LndAc_S             0
# ImpAc_S             0
# OthAc_S             0
# TtlVal_AsrYr        0
# ValType             0
# X1TPr_D         21519
# X1TSc_D         21519
# X2TPr_D         22212
# X2TSc_D         22212
# X1TPr_S         21522
# X1TSc_S         21522
# X2TPr_S         22212
# X2TSc_S         22212
# ...

# %%
House2['MapRefNo'].equals(House2['GeoRefNo'])
# Out:
# False

# %%
df[df['H'].isnull()]

# %%
House2[House2["Prop_Addr"].isnull()]
# Out:
#          MapRefNo    GeoRefNo  Tier  Range Prop_Addr ZngCdPr ZngCdSc ZngOLPr  \
# 4769    533210020   533210020     0      0       NaN    F-VR     NaN     NaN
# 7686    594010010   594010010     0      0       NaN     NaN     NaN     NaN
# 11657   906910100   906910100     0      0       NaN     NaN     NaN     NaN
# 11658   906930100   906930100     0      0       NaN     NaN     NaN     NaN
# 18094   911350045   911350045     0      0       NaN      RH     HOC     O-E
# 19053   915930100   915930100     0      0       NaN     NaN     NaN     NaN
# 20031   921200125   921200125     0      0       NaN       A     NaN     NaN
# 20032   921200130   921200130     0      0       NaN       A     NaN     NaN
# 20035   921200305   921200305     0      0       NaN       A     NaN     NaN
# 20036   921200320   921200320     0      0       NaN       A     NaN     NaN
# 20039   921200450   921200450     0      0       NaN       A     NaN     NaN
# ...

# %%
# !pip install geopandas
# Out:
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Francesco\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Francesco\\AppData\\Local\\Temp\\pip-install-5kdhl03j\\fiona_6c3196f046a246509b5c9eb0f398f0ff\\setup.py'"'"'; __file__='"'"'C:\\Users\\Francesco\\AppData\\Local\\Temp\\pip-install-5kdhl03j\\fiona_6c3196f046a246509b5c9eb0f398f0ff\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Francesco\AppData\Local\Temp\pip-pip-egg-info-37rma1cz'
#          cwd: C:\Users\Francesco\AppData\Local\Temp\pip-install-5kdhl03j\fiona_6c3196f046a246509b5c9eb0f398f0ff\
#     Complete output (1 lines):
# ...

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent = "MyGeocoder")
location = locator.geocode(House2["Prop_Addr"])
print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))


loc = Nominatim(user_agent="GetLoc")
 
# entering the location name
getLoc = loc.geocode("Gosainganj Lucknow")
 
# printing address
print(getLoc.address)
 
# printing latitude and longitude
print("Latitude = ", getLoc.latitude, "\n")
print("Longitude = ", getLoc.longitude)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/2737186722.py in <module>
#       2 locator = Nominatim(user_agent = "MyGeocoder")
#       3 location = locator.geocode(House2["Prop_Addr"])
# ----> 4 print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent = "MyGeocoder")
location = locator.geocode(House2["Prop_Addr"])
print(location.latitude)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/2004574059.py in <module>
#       2 locator = Nominatim(user_agent = "MyGeocoder")
#       3 location = locator.geocode(House2[["Prop_Addr"]])
# ----> 4 print(location.latitude)
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent = "MyGeocoder")
lat = []
long = []
for row in House2["Prop_Addr"]:
    addr = locator.geocode(row, timeout=10)
    if addr is None or addr == "NaN" or addr == "":
        lat.append(None)
        long.append(None)
    else:
        latitude = ad.latitude
        longitude = ad.longitude  
    
    lat.append(latitude)
    long.append(longitude)

House2['latitude'] = lat
House2['longitude'] = long
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\FRANCE~1\AppData\Local\Temp/ipykernel_25380/2567835703.py in <module>
#      12         longitude = ad.longitude
#      13
# ---> 14     lat.append(latitude)
#      15     long.append(longitude)
#      16
#
# NameError: name 'latitude' is not defined

# %%
import pandas
from geopy.geocoders import Nominatim

geolocator = Nominatim()
for index, item in df.iterrows():
    location = geolocator.geocode(item)
    df["Latitude"].append(location.latitude)
    df["Longitude"].append(location.longitude)

# %%
House2['SaleType'][98]
# Out:
# 'WRDConv'

# %%
House2.loc[House2["YrSold_YYYY"] == 2008 ]
# Out:
# Empty DataFrame
# Columns: [MapRefNo, GeoRefNo, Tier, Range, Prop_Addr, ZngCdPr, ZngCdSc, ZngOLPr, ZngOLSc, ClassPr_S, ClassSc_S, Legal_Pr, SchD_S, TxD_S, MA_Ownr1, MA_Ownr2, MA_Line1, MA_Line2, MA_City, MA_State, MA_Zip1, MA_Zip2, Rcrd_Yr, Rcrd_Mo, Inst1_No, Inst1_Yr, Inst1_Mo, Inst1TPr, LndAc_S, ImpAc_S, OthAc_S, TtlVal_AsrYr, ValType, X1TPr_D, X1TSc_D, X2TPr_D, X2TSc_D, X1TPr_S, X1TSc_S, X2TPr_S, X2TSc_S, LndAcX1S, ImpAcX1S, ImpAcX2S, HSTtl_D, MilVal_D, HSTtl_S, MilVal_S, AcreX_S1, AcreGr, AcreNt_S, Neighborhood, LotArea, ParType, BldgNo_S, DwlgNo_S, BldgType, YrBuilt, HouseStyle, Foundation, RoofMatl, Ext1, Ext2, MasVnrType, Heating, Central Air, GLA, TtlBsmtSF, TotRmsAbvGrd, Fireplaces, PoolArea, GarageType, GarYrBlt, Cars, GarageArea, YrSold_YYYY, MoSold_MM, SalePrice, SaleType, SaleCond, ParclRel, PA-Nmbr, PA-PreD, PA-Strt, PA-StSfx, PA-PostD, PA-UnTyp, PA-UntNo, Date, Source, NmbrBRs]
# Index: []
#
# [0 rows x 91 columns]

# %%
House2["YrSold_YYYY"].unique()
# Out:
# array([  nan, 2019., 2017., 2018., 2020.])

# %%
HousePriceDF["YrSold"].unique()
# Out:
# array([2010, 2009, 2007, 2008, 2006], dtype=int64)
