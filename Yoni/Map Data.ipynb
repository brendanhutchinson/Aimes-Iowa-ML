# %%
import pandas as pd 
import numpy as np 
pd.options.display.max_rows = 100

mapdata = pd.read_csv("C:/Users/ykorn/Downloads/Ames_Real_Estate_Data.csv")
mapdata
# Out:
# C:\Users\ykorn\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (36,40,81,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          MapRefNo    GeoRefNo  Tier  Range                 Prop_Addr ZngCdPr  \
# 0       520400001   520400001     0      0  4599 GEORGE W CARVER AVE   FS-RL
# 1       520440010   520440010     0      0         4507 EVEREST  AVE   FS-RL
# 2       520440020   520440020     0      0         4513 EVEREST  AVE   FS-RL
# 3       520445001   520445001     0      0          3449 BARCELOS ST   FS-RL
# 4       520445010   520445010     0      0         4506 EVEREST  AVE   FS-RL
# ...           ...         ...   ...    ...                       ...     ...
# 22208  1018100010  1018100010     0      0           2400 SE 16TH ST     HOC
# 22209  1018100025  1018100025     0      0           2500 SE 16TH ST     HOC
# ...

# %%
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent='ykornblau@gmail.com')

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# 2- - create location column
df = mapdata['Prop_Addr'].head() +', IA'
df.apply(geocode)
# # 3 - create longitude, laatitude and altitude from location column (returns tuple)
# df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# # 4 - split point column into latitude, longitude and altitude columns
# df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)
df
#for i in mapdata['Prop_Addr']:
#     try:
        
#         location = locator.geocode(i+ 'Ames,IA')
#         print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
#     except:
#         continue
# Out:
# 0    4599 GEORGE W CARVER AVE, IA
# 1           4507 EVEREST  AVE, IA
# 2           4513 EVEREST  AVE, IA
# 3            3449 BARCELOS ST, IA
# 4           4506 EVEREST  AVE, IA
# Name: Prop_Addr, dtype: object

# %%
for i in df:
    try:
        location = locator.geocode(i)
        print(i  + ' location: Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
    except:
        continue
# Out:
# 4507 EVEREST  AVE, Ames, IA location: Latitude = 42.0641906, Longitude = -93.6623098
# 4513 EVEREST  AVE, Ames, IA location: Latitude = 42.0641906, Longitude = -93.6623098
# 3449 BARCELOS ST, Ames, IA location: Latitude = 42.0640941, Longitude = -93.6615943
# 4506 EVEREST  AVE, Ames, IA location: Latitude = 42.0641906, Longitude = -93.6623098

# %%
for i in df:
    try:
        location = locator.geocode(i)
        print(i  + ' location: Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
    except:
        continue
# Out:
# 4507 EVEREST  AVE, IA location: Latitude = 42.0641906, Longitude = -93.6623098
# 4513 EVEREST  AVE, IA location: Latitude = 42.0641906, Longitude = -93.6623098
# 3449 BARCELOS ST, IA location: Latitude = 42.0640941, Longitude = -93.6615943
# 4506 EVEREST  AVE, IA location: Latitude = 42.0641906, Longitude = -93.6623098

# %%
mapdata['Prop_Addr'].head()
# Out:
# 0    4599 GEORGE W CARVER AVE
# 1           4507 EVEREST  AVE
# 2           4513 EVEREST  AVE
# 3            3449 BARCELOS ST
# 4           4506 EVEREST  AVE
# Name: Prop_Addr, dtype: object
